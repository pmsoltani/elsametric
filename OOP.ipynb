# %%
# Modules
import json
import io
import os

# %%
# functions
def imp(file:str, folder:str=''):
    path = os.path.join(folder, file)
    with io.open(path, 'r', encoding='utf8') as f:
        data = json.load(f)
    return data

# %%
# OOP

class Institution:
    pass

class Author:
    
    def __init__(self, name, author_id):
        self.name = name
        self.id = author_id

class Journal:
    pass

class Publication:
    pass

# %%
# Playground
simchi = Author('Arash', '1227')
simchi.id

data = imp('Sharif University of Technology_y2011_001_OSNURM_1558340225.txt')
print(type(data))
data
# Out:
# <class 'dict'>
# {'search-results': {'entry': [{'@_fa': 'true',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-city': 'Tehran',
#       'affiliation-country': 'Iran',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027666',
#       'affilname': 'Sharif University of Technology',
#       'afid': '60027666'}],
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'afid': [{'$': '60027666', '@_fa': 'true'}],
#       'authid': '54782457900',
#       'authname': 'Firouzbahrami M.',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/54782457900',
#       'given-name': 'Majid',
#       'initials': 'M.',
#       'surname': 'Firouzbahrami'},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'afid': [{'$': '60027666', '@_fa': 'true'}],
#       'authid': '8713049500',
#       'authname': 'Nobakhti A.',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/8713049500',
# ...

# %%
a=[1,2,'aw','bb',4]
a.remove('aw')
a
# Out:
# [1, 2, 'bb', 4]
